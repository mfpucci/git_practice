# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
#importing appropriate librarys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#load the Kansas City housing data
df = pd.read_csv('kc_house_data.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
#From the above visual, you can see that sqft_basement has 21597 non-null objects.  Lets dig deeper into this.
df.sqft_basement.value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
# 400.0       184
# 1000.0      148
# 900.0       142
# 300.0       142
# 200.0       105
# 750.0       104
# 450.0       103
# 480.0       103
# 530.0       103
# 720.0        98
# 620.0        90
# 580.0        84
# 840.0        83
# 420.0        81
# 860.0        79
# 670.0        78
# 1100.0       78
# 780.0        76
# 550.0        76
# 650.0        75
# 240.0        74
# 380.0        73
# 680.0        73
# 360.0        72
#           ...
# 2500.0        1
# 417.0         1
# 2390.0        1
# 276.0         1
# 666.0         1
# 176.0         1
# 207.0         1
# 2120.0        1
# 2310.0        1
# 1275.0        1
# 1481.0        1
# 2600.0        1
# 862.0         1
# 1548.0        1
# 1816.0        1
# 2610.0        1
# 2180.0        1
# 172.0         1
# 652.0         1
# 1135.0        1
# 915.0         1
# 374.0         1
# 415.0         1
# 2196.0        1
# ...

# %%
#There are 454 observations that fall under '?'.  We will now remove these values and replace them with the mean of the sqft_basement
df.sqft_basement.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     821         try:
# --> 822             x = float(x)
#     823         except Exception:
#
# ...
